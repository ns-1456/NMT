# %% [markdown]
# # English-Gujarati NMT Analysis
#
# This notebook contains exploratory data analysis and visualization for the English-Gujarati NMT project.

# %%
import sys
from pathlib import Path

# Add src to path
sys.path.insert(0, str(Path('..').resolve()))

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from src.utils.config import load_config

# %% [markdown]
# ## Data Analysis
#
# Add your data analysis code here.

# %%
# Load config
config = load_config('../config.yaml')

# Example: Load and analyze data
# Add your analysis code here
